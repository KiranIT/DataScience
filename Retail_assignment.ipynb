# %%
import pandas as pd
import nudf1=retail.sort_values(by='Sales',ascending=False)
df1.head()mpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Order sales data_01.csv' ,encoding = 'latin-1')

# %%
#2
df1=data.sort_values(by='Sales',ascending=False)
df1.head(1)
# Out:
#       Row ID  Order ID  Order Date Order Priority  Order Quantity     Sales  \
# 4189    4190     29766  21-03-2009         Medium              13  89061.05
#
#       Discount    Ship Mode    Profit  Unit Price  ...  Customer Name  \
# 4189       0.0  Regular Air  27220.69     6783.02  ...     Emily Phan
#
#            Province    Region Customer Segment Product Category  \
# 4189  New Brunswick  Atlantic         Consumer       Technology
#
#      Product Sub-Category                                      Product Name  \
# 4189      Office Machines  Polycom ViewStation ISDN Videoconferencing Unit
#
#      Product Container Product Base Margin   Ship Date
# 4189         Large Box                0.39  22-03-2009
#
# [1 rows x 21 columns]

# %%
#3
data.corr()
# Out:
#                        Row ID  Order ID  Order Quantity     Sales  Discount  \
# Row ID               1.000000  0.999961        0.011103 -0.007560 -0.003289
# Order ID             0.999961  1.000000        0.010953 -0.007792 -0.003213
# Order Quantity       0.011103  0.010953        1.000000  0.220582 -0.009649
# Sales               -0.007560 -0.007792        0.220582  1.000000 -0.019686
# Discount            -0.003289 -0.003213       -0.009649 -0.019686  1.000000
# Profit              -0.006605 -0.006820        0.194655  0.581960 -0.037128
# Unit Price          -0.004115 -0.004304       -0.104284  0.602521  0.001332
# Shipping Cost       -0.004713 -0.004582       -0.011457  0.434578 -0.001956
# Product Base Margin -0.022726 -0.022557        0.007839  0.156759  0.004079
#
#                        Profit  Unit Price  Shipping Cost  Product Base Margin
# Row ID              -0.006605   -0.004115      -0.004713            -0.022726
# ...

# %%
#4
s = data.sort_values(by='Sales',ascending=False)
s.head(5)
# Out:
#       Row ID  Order ID  Order Date Order Priority  Order Quantity     Sales  \
# 4189    4190     29766  21-03-2009         Medium              13  89061.05
# 451      452      3073  07-01-2009         Medium               7  45923.76
# 4263    4264     30343  21-05-2012       Critical               8  41343.21
# 2025    2026     14435  01-12-2012  Not Specified               9  33367.85
# 4628    4629     32932  09-01-2010            Low              49  29884.60
#
#       Discount    Ship Mode    Profit  Unit Price  ...    Customer Name  \
# 4189      0.00  Regular Air  27220.69     6783.02  ...       Emily Phan
# 451       0.07  Regular Air    102.61     6783.02  ...  Jasper Cacioppo
# 4263      0.09  Regular Air   3852.19     6783.02  ...   Craig Carreira
# 2025      0.01  Regular Air   3992.52     3499.99  ...      Dennis Kane
# 4628      0.05  Regular Air  12748.86      599.99  ...   Karen Carlisle
#
#               Province    Region Customer Segment Product Category  \
# ...

# %%
#5
data.sort_values(by='Profit',ascending=False)
# Out:
#       Row ID  Order ID  Order Date Order Priority  Order Quantity     Sales  \
# 4189    4190     29766  21-03-2009         Medium              13  89061.05
# 1315    1316      9637  03-01-2009            Low              49  28359.40
# 2908    2909     20967  15-03-2011           High              50  28664.52
# 4628    4629     32932  09-01-2010            Low              49  29884.60
# 4095    4096     29187  31-07-2009            Low              35  26095.13
# ...      ...       ...         ...            ...             ...       ...
# 3197    3198     22917  01-03-2009         Medium               1   3550.28
# 6085    6086     43110  06-02-2011           High               1   3457.99
# 7222    7223     51553  27-11-2011  Not Specified               3  21366.51
# 6075    6076     43044  17-10-2009         Medium               3  19707.20
# 5212    5213     37095  10-03-2009            Low               3  18888.00
#
# ...

# %%
data.groupby('Ship Mode').sum()
# Out:
#                   Row ID   Order ID  Order Quantity        Sales  Discount  \
# Ship Mode
# Delivery Truck   4802592   34272320           28764  6224878.718     57.06
# Express Air      4252650   30339491           25353  1184418.897     49.10
# Regular Air     26220558  187065734          160660  7506303.209    311.03
#
#                       Profit  Unit Price  Shipping Cost  Product Base Margin
# Ship Mode
# Delivery Truck  2.696448e+05   302189.89       51971.94               701.69
# Express Air     1.474303e+05    56024.90        7850.91               490.55
# Regular Air     1.104693e+06   392204.44       48008.19              3080.07
